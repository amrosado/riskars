# %%
import os
import sys
import pickle

# %%
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  '20150103_aaron_pickles.ipynb',
#  'brfssData1995.pickle',
#  'brfssData1996.pickle',
#  'brfssData1997.pickle',
#  'brfssData1998.pickle']

# %%
pickle_filename = 'brfssData1996.pickle'
l_brfssData1996 = pickle.load( open( pickle_filename, "rb" ) )

# %%
len(l_brfssData1996)
# Out:
# 1165

# %%
l_brfssData1996[0]
# Out:
# {'displayData': [{'data': [{'tableData': [[u'\xa0',
#        u'18-24 years',
#        u'25-34 years',
#        u'35-44 years',
#        u'45-54 years',
#        u'55-64 years',
#        u'65+ years'],
#       [[[u'Median %', u'# States'],
#         [u'12.3', u'51'],
#         [u'20.4', u'51'],
#         [u'21.4', u'51'],
#         [u'16.6', u'51'],
#         [u'11.1', u'51'],
#         [u'18.1', u'51']]]],
#      'tableInfo': {'cat': u'DE',
#       'qkey': u'187',
#       'state': u'US',
#       'yr': u'1996'}},
#     {'tableData': [[u'Gender:',
#        u'\xa0',
#        u'18-24 years',
#        u'25-34 years',
#        u'35-44 years',
#        u'45-54 years',
#        u'55-64 years',
#        u'65+ years'],
#       [u'Male',
#        [[u'Median %', u'# States'],
#         [u'13.1', u'51'],
#         [u'21.6', u'51'],
#         [u'22.1', u'51'],
#         [u'17.0', u'51'],
#         [u'11.1', u'51'],
#         [u'15.1', u'51']]],
#       [u'Female',
# ...
